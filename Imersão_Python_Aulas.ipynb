# %% [markdown]
# <a href="https://colab.research.google.com/github/Liaelis/imersao_python/blob/main/Imers%C3%A3o_Python_Aulas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 2 -Importação

# %%
import pandas as pd
import plotly.express as px

# %%
def_principal = pd.read_excel("/tabela_acoes.xlsx",sheet_name="Principal")

# %%
def_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5  PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6  PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7  VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8  MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9  ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  Variação %  \
# ...

# %%
def_total_acoes = pd.read_excel("/tabela_acoes.xlsx",sheet_name="Total_de_acoes")
def_total_acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   2.356656e+08
# 1  ALOS3   5.326166e+08
# 2  ALPA4   1.767340e+08
# 3  ABEV3   4.394246e+09
# 4  ARZZ3   6.230589e+07
# 5  ASAI3   1.349218e+09
# 6  AZUL4   3.275937e+08
# 7  B3SA3   5.602790e+09
# 8  BBSE3   6.717508e+08
# 9  BBDC3   1.500729e+09

# %%
def_ticker = pd.read_excel("tabela_acoes.xlsx",sheet_name="Ticker")
def_ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
def_chatgpt = pd.read_excel("/tabela_acoes.xlsx",sheet_name="Chatgpt")
def_chatgpt.head(10)
# Out:
#   Nome da empresa          Segmento  Idade (anos)
# 0        Usiminas        Siderurgia            60
# 1   CSN Mineração         Mineração             8
# 2       Petrobras          Petróleo            69
# 3          Suzano  Papel e Celulose            94
# 4    CPFL Energia           Energia           109
# 5        PetroRio          Petróleo             9
# 6       Petrobras          Petróleo            69
# 7            Vale         Mineração            79
# 8       Multiplan  Shopping Centers            48
# 9   Itaú Unibanco             Banco            13

# %%
def_principal=def_principal[['Ativo','Data','Último (R$)', 'Var. Dia (%)']].copy()

# %%
def_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)
# 0  USIM5 2024-01-26         9.50          5.20
# 1  CMIN3 2024-01-26         6.82          2.40
# 2  PETR3 2024-01-26        41.96          2.19
# 3  SUZB3 2024-01-26        52.91          2.04
# 4  CPFE3 2024-01-26        37.10          2.03
# 5  PRIO3 2024-01-26        45.69          1.98
# 6  PETR4 2024-01-26        39.96          1.73
# 7  VALE3 2024-01-26        69.50          1.66
# 8  MULT3 2024-01-26        28.19          1.58
# 9  ITUB4 2024-01-26        32.81          1.48

# %%
def_principal= def_principal.rename(columns={'Último (R$)': 'valor_final', 'Var. Dia (%)':'var_dia_pct'}).copy()

# %% [markdown]
# funçao copy() faz com que seja criado e substituido o dataframe

# %%
def_principal.head(10)
# Out:
#    Ativo       Data  valor_final  var_dia_pct
# 0  USIM5 2024-01-26         9.50         5.20
# 1  CMIN3 2024-01-26         6.82         2.40
# 2  PETR3 2024-01-26        41.96         2.19
# 3  SUZB3 2024-01-26        52.91         2.04
# 4  CPFE3 2024-01-26        37.10         2.03
# 5  PRIO3 2024-01-26        45.69         1.98
# 6  PETR4 2024-01-26        39.96         1.73
# 7  VALE3 2024-01-26        69.50         1.66
# 8  MULT3 2024-01-26        28.19         1.58
# 9  ITUB4 2024-01-26        32.81         1.48

# %%
def_principal['var_pct']= def_principal['var_dia_pct']/100

# %%
def_principal['valor_inicial']= def_principal['valor_final']/(def_principal['var_pct']+1)

# %%
def_principal.head(10)
# Out:
#    Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial
# 0  USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1  CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2  PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3  SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4  CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# 5  PRIO3 2024-01-26        45.69         1.98   0.0198      44.802903
# 6  PETR4 2024-01-26        39.96         1.73   0.0173      39.280448
# 7  VALE3 2024-01-26        69.50         1.66   0.0166      68.365139
# 8  MULT3 2024-01-26        28.19         1.58   0.0158      27.751526
# 9  ITUB4 2024-01-26        32.81         1.48   0.0148      32.331494

# %%
def_principal=def_principal.merge(def_total_acoes,left_on='Ativo', right_on='Código',how='left')

# %%
def_principal.head(10)
# Out:
#    Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial Código  \
# 0  USIM5 2024-01-26         9.50         5.20   0.0520       9.030418  USIM5
# 1  CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156  CMIN3
# 2  PETR3 2024-01-26        41.96         2.19   0.0219      41.060769  PETR3
# 3  SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215  SUZB3
# 4  CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854  CPFE3
# 5  PRIO3 2024-01-26        45.69         1.98   0.0198      44.802903  PRIO3
# 6  PETR4 2024-01-26        39.96         1.73   0.0173      39.280448  PETR4
# 7  VALE3 2024-01-26        69.50         1.66   0.0166      68.365139  VALE3
# 8  MULT3 2024-01-26        28.19         1.58   0.0158      27.751526  MULT3
# 9  ITUB4 2024-01-26        32.81         1.48   0.0148      32.331494  ITUB4
#
#    Qtde. Teórica
# 0   5.151174e+08
# 1   1.110559e+09
# 2   2.379878e+09
# 3   6.834528e+08
# 4   1.877325e+08
# ...

# %%
def_principal= def_principal.drop(columns=['Código'])

# %%
def_principal.head(10)
# Out:
#    Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0  USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1  CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2  PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3  SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4  CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# 5  PRIO3 2024-01-26        45.69         1.98   0.0198      44.802903
# 6  PETR4 2024-01-26        39.96         1.73   0.0173      39.280448
# 7  VALE3 2024-01-26        69.50         1.66   0.0166      68.365139
# 8  MULT3 2024-01-26        28.19         1.58   0.0158      27.751526
# 9  ITUB4 2024-01-26        32.81         1.48   0.0148      32.331494
#
#    Qtde. Teórica
# 0   5.151174e+08
# 1   1.110559e+09
# 2   2.379878e+09
# 3   6.834528e+08
# 4   1.877325e+08
# 5   8.000107e+08
# 6   4.566446e+09
# 7   4.196924e+09
# 8   2.685054e+08
# ...

# %%
def_principal['variacao_rs'] = (def_principal['valor_final']- def_principal['valor_inicial'])*def_principal['Qtde. Teórica']

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
def_principal.head(10)
# Out:
#    Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0  USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1  CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2  PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3  SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4  CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5  PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6  PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7  VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8  MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9  ITUB4 2024-01-26        32.81         1.48     0.01          32.33
#
#    Qtde. Teórica   variacao_rs
# 0   515117391.00  241889725.43
# 1  1110559345.00  177515970.30
# 2  2379877655.00 2140059393.53
# 3   683452836.00  722946282.71
# 4   187732538.00  138573955.06
# ...

# %%
def_principal['Qtde. Teórica'
] = def_principal['Qtde. Teórica'
].astype(int)

# %%
def_principal.head(10)
# Out:
#    Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0  USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1  CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2  PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3  SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4  CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5  PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6  PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7  VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8  MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9  ITUB4 2024-01-26        32.81         1.48     0.01          32.33
#
#    Qtde. Teórica   variacao_rs
# 0      515117391  241889725.43
# 1     1110559345  177515970.30
# 2     2379877655 2140059393.53
# 3      683452836  722946282.71
# 4      187732538  138573955.06
# ...

# %%
def_principal= def_principal.rename(columns={'Qtde. Teórica': 'qtd_teorica'}).copy()

# %%
def_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# ...

# %%
def_principal['resultado']= def_principal['variacao_rs'].apply(lambda x: 'Subiu' if x > 0 else('Desceu' if x < 0 else 'Estavel'))

# %%
def_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado
# 0     515117391   241889725.43     Subiu
# ...

# %%
def_principal= def_principal.merge(def_ticker, left_on='Ativo',right_on='Ticker', how='left')
def_principal= def_principal.drop(columns=['Ticker'])

# %%
def_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado              Nome
# ...

# %%
def_principal= def_principal.merge(def_chatgpt, left_on='Nome',right_on='Nome da empresa', how='left')
def_principal= def_principal.drop(columns=['Nome da empresa'])

# %%
def_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 83  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 84  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 85  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 86  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado              Nome           Segmento  \
# ...

# %%
def_principal['cat_idade']= def_principal['Idade (anos)'].apply(lambda x : 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else 'Entre 50 e 100'))
def_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# ..    ...        ...          ...          ...      ...            ...
# 82  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 83  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 84  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 85  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 86  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     qtd_teorica    variacao_rs resultado              Nome           Segmento  \
# ...

# %%
maior = def_principal['variacao_rs'].max()
menor = def_principal['variacao_rs'].min()
media = def_principal['variacao_rs'].mean()
media_subiu = def_principal[def_principal['resultado']=='Subiu']['variacao_rs'].mean()
media_desceu = def_principal[def_principal['resultado']=='Desceu']['variacao_rs'].mean()

# %%
maior
# Out:
# 4762926995.24809

# %%
menor
# Out:
# -1807432634.4595425

# %%
media_subiu
# Out:
# 538720638.3614079

# %%
media_desceu
# Out:
# -186265310.45906794

# %%
def_principal_subiu =  def_principal[def_principal['resultado']=='Subiu']

# %% [markdown]
# reset_index é pra continuar sendo um dataframe

# %%
df_analise_segmento = def_principal_subiu.groupby('Segmento')['variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#               Segmento    variacao_rs
# 0            Alimentos   407833683.09
# 1              Aviação    65452205.55
# 2                Banco  4636679965.25
# 3           Construção    37525872.38
# 4             Educação    72295838.99
# 5              Energia  1209821623.57
# 6              Holding   416092244.42
# 7          Imobiliário    18068446.61
# 8            Logística   233902674.79
# 9   Meios de Pagamento    43657683.38
# 10           Mineração  4940442965.55
# 11                Moda    41021792.09
# 12    Papel e Celulose   722946282.71
# 13            Petróleo 11336484517.00
# 14             Química    69054317.64
# 15               Saúde   453917907.01
# 16    Shopping Centers   117732680.08
# 17          Siderurgia   489935930.93
# 18          Tecnologia    15598886.65
# 19    Telecomunicações   292938114.42
# 20              Varejo   237187009.24

# %%
df_analise_saldo = def_principal.groupby('resultado')['variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   resultado    variacao_rs
# 0    Desceu -6891816486.99
# 1   Estavel           0.00
# 2     Subiu 25858590641.35

# %%
fig = px.bar(df_analise_saldo,x='resultado', y= 'variacao_rs', text='variacao_rs', title='Variacao reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pip install --upgrade mplfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 2.6 MB/s eta 0:00:00
# ...

# %%
pip install plotly

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import mplfinance as mpf
import yfinance as yf
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
dados = yf.download('PETR4.SA',start='2023-01-01', end='2023-12-31')
dados
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close     Volume
# Date
# 2023-01-02 23.54 23.81 22.80  22.92      17.71   78424700
# 2023-01-03 22.94 23.10 22.13  22.34      17.26   96750300
# 2023-01-04 21.96 23.59 21.83  23.05      17.81  129504000
# 2023-01-05 23.34 24.04 23.15  23.88      18.45   73886000
# 2023-01-06 23.94 24.32 23.55  23.74      18.34   51851500
# ...          ...   ...   ...    ...        ...        ...
# 2023-12-21 36.67 36.68 36.07  36.39      36.39   30511900
# 2023-12-22 36.50 36.80 36.37  36.74      36.74   31234700
# 2023-12-26 36.86 37.37 36.83  37.33      37.33   23466800
# 2023-12-27 37.32 37.43 37.13  37.36      37.36   19588500
# 2023-12-28 37.23 37.36 37.04  37.24      37.24   21421900
#
# [248 rows x 6 columns]

# %%
dados.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
dados.columns=['Abertura', 'Maximo', 'Minimo', 'Fechamento', 'Fech_Ajust', 'Volume']

# %%
dados
# Out:
#             Abertura  Maximo  Minimo  Fechamento  Fech_Ajust     Volume
# Date
# 2023-01-02     23.54   23.81   22.80       22.92       17.71   78424700
# 2023-01-03     22.94   23.10   22.13       22.34       17.26   96750300
# 2023-01-04     21.96   23.59   21.83       23.05       17.81  129504000
# 2023-01-05     23.34   24.04   23.15       23.88       18.45   73886000
# 2023-01-06     23.94   24.32   23.55       23.74       18.34   51851500
# ...              ...     ...     ...         ...         ...        ...
# 2023-12-21     36.67   36.68   36.07       36.39       36.39   30511900
# 2023-12-22     36.50   36.80   36.37       36.74       36.74   31234700
# 2023-12-26     36.86   37.37   36.83       37.33       37.33   23466800
# 2023-12-27     37.32   37.43   37.13       37.36       37.36   19588500
# 2023-12-28     37.23   37.36   37.04       37.24       37.24   21421900
#
# [248 rows x 6 columns]

# %%
dados = dados.rename_axis('Data')

# %%
dados['Fechamento'].plot(figsize=(10,6))
plt.title('Variaçao do preço por data', fontsize=16)
plt.legend(['Fechamento'])

# %%
df = dados.head(60).copy()
df['Data'] = df.index
df['Data'] = df['Data'].apply(mdates.date2num)

# %%
df
# Out:
#             Abertura  Maximo  Minimo  Fechamento  Fech_Ajust     Volume  \
# Data
# 2023-01-02     23.54   23.81   22.80       22.92       17.71   78424700
# 2023-01-03     22.94   23.10   22.13       22.34       17.26   96750300
# 2023-01-04     21.96   23.59   21.83       23.05       17.81  129504000
# 2023-01-05     23.34   24.04   23.15       23.88       18.45   73886000
# 2023-01-06     23.94   24.32   23.55       23.74       18.34   51851500
# 2023-01-09     23.50   24.00   23.25       23.87       18.44   46385200
# 2023-01-10     23.95   24.11   23.37       24.09       18.61   52741100
# 2023-01-11     24.15   24.62   24.05       24.28       18.76   53536500
# 2023-01-12     24.29   24.65   24.11       24.63       19.03   58130000
# 2023-01-13     24.44   24.66   24.25       24.57       18.98   40002700
# 2023-01-16     24.41   24.50   23.83       24.04       18.57   31973700
# 2023-01-17     24.11   25.62   24.11       25.52       19.72   91797500
# ...

# %%
from pathlib import WindowsPath
fig, ax = plt.subplots(figsize=(15,8))
width = 0.7
for i in range(len(df)):
  if df['Fechamento'].iloc[i] > df['Abertura'].iloc[i]:
    color = 'green'
  else:
    color = 'red'


  ax.plot([df['Data'].iloc[i], df['Data'].iloc[i]],
          [df['Minimo'].iloc[i], df['Maximo'].iloc[i]],
          color=color, linewidth=1)
  ax.add_patch(plt.Rectangle((df['Data'].iloc[i] - width/2, min (df['Abertura'].iloc[i], df['Fechamento'].iloc[i])),
                             width,
                             abs(df['Fechamento'].iloc[i] - df['Abertura'].iloc[i]),
                             facecolor = color))

df['MA7']= df['Fechamento'].rolling(window=7).mean()
df['MA14'] = df['Fechamento'].rolling(window=14).mean()

ax.plot(df['Data'], df['MA7'], color='orange', label = 'Média Móvel 7 dias')
ax.plot(df['Data'], df['MA14'], color='yellow', label = 'Média Móvel 14 dias')
ax.legend()


ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45)

plt.title('Gráfico de Candleestick - PETR4.SA com matplotlib')
plt.xlabel('Data')
plt.ylabel('Preço')

plt.grid(True)

plt.show()

# %%
fig = make_subplots(rows=2,cols=1, shared_xaxes=True,
                    vertical_spacing=0.1,
                    subplot_titles=('Cadlestick', 'Volume Transacionado'),
                    row_width=[0.2,0.7])

fig.add_trace(go.Candlestick(x=df.index,
                             open=df['Abertura'],
                             high=df['Maximo'],
                             low=df['Minimo'],
                             close=df['Fechamento'],
                             name='Candlestick'  ),
                             row=1, col=1)

fig.add_trace(go.Scatter(x=df.index,
                          y=df['MA7'],
                          mode='lines',
                          name='MA& - Média Móvel 7 dias'),
                          row=1,col=1)

fig.add_trace(go.Scatter(x=df.index,
                          y=df['MA14'],
                          mode='lines',
                          name='MA& - Média Móvel 14 dias'),
                          row=1,col=1)

fig.add_trace(go.Bar(x=df.index,
                     y = df['Volume'],
                     name= 'Volume'),
              row=2, col=1)
fig.update_layout(yaxis_title='Preço',
                  xaxis_rangeslider_visible=False,
                  width=1100, height=600)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Criar a figura com subplots
fig = make_subplots(rows=2, cols=1)

# Adicionar traço de Candlestick
fig.add_trace(go.Candlestick(x=df.index,
                             open=df['Abertura'],
                             high=df['Maximo'],
                             low=df['Minimo'],
                             close=df['Fechamento'],
                             name='Candlestick'),
              row=1, col=1)

# Adicionar traço de Média Móvel de 7 dias
fig.add_trace(go.Scatter(x=df.index,
                         y=df['MA7'],
                         mode='lines',
                         name='MA7 - Média Móvel 7 dias'),
              row=1, col=1)

# Adicionar traço de Média Móvel de 14 dias
fig.add_trace(go.Scatter(x=df.index,
                         y=df['MA14'],
                         mode='lines',
                         name='MA14 - Média Móvel 14 dias'),
              row=1, col=1)

# Adicionar traço de volume
fig.add_trace(go.Bar(x=df.index,
                     y=df['Volume'],
                     name='Volume'),
              row=2, col=1)

# Atualizar layout da figura
fig.update_layout(yaxis_title='Preço',
                  xaxis_rangeslider_visible=False,
                  width=1100, height=600)

# Mostrar figura
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dados_originais = yf.download('PETR4.SA',start='2023-01-01', end='2023-12-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
mpf.plot(dados_originais.head(30), type='candle', figsize= (16,8), volume=True,mav=(7,14), style='yahoo' )

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
dados = yf.download('JNJ', start='2020-01-01', end='2023-12-31', progress= False)
dados = dados.reset_index()

# %%
dados
# Out:
#            Date   Open   High    Low  Close  Adj Close   Volume
# 0    2020-01-02 145.87 146.02 145.08 145.97     130.10  5777000
# 1    2020-01-03 143.50 145.37 143.00 144.28     128.59  5752400
# 2    2020-01-06 144.00 144.20 142.85 144.10     128.43  7731300
# 3    2020-01-07 144.01 145.45 141.38 144.98     129.22  7382900
# 4    2020-01-08 144.87 145.98 143.70 144.96     129.20  6605800
# ...         ...    ...    ...    ...    ...        ...      ...
# 1001 2023-12-22 155.25 156.53 155.02 155.46     154.29  3798500
# 1002 2023-12-26 155.00 156.35 154.85 156.14     154.96  4170000
# 1003 2023-12-27 155.50 156.52 155.42 156.35     155.17  5288100
# 1004 2023-12-28 156.00 157.24 155.99 156.58     155.40  4377500
# 1005 2023-12-29 156.51 156.90 155.98 156.74     155.56  4311100
#
# [1006 rows x 7 columns]

# %%
dados_treino = dados[dados['Date'] < '2023-07-31']
dados_teste = dados[dados['Date'] >= '2023-07-31']

# %%
dados_prophet_treino = dados_treino[['Date', 'Close']].rename(columns={'Date':'ds', 'Close':'y'})

# %%
modelo = Prophet(weekly_seasonality=True,
                 yearly_seasonality=True,
                 daily_seasonality=False)

modelo.add_country_holidays(country_name='US')
modelo.fit(dados_prophet_treino)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiub740we/in87a7u6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpiub740we/oboqnbh9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28609', 'data', 'file=/tmp/tmpiub740we/in87a7u6.json', 'init=/tmp/tmpiub740we/oboqnbh9.json', 'output', 'file=/tmp/tmpiub740we/prophet_modele73po2la/prophet_model-20240401151743.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 15:17:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 15:17:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
futuro = modelo.make_future_dataframe(periods=150)
previsao = modelo.predict(futuro)

# %%
plt.figure(figsize=(14,8))
plt.plot(dados_treino['Date'], dados_treino['Close'], label= 'Dados de Treino', color = 'blue')
plt.plot(dados_teste['Date'], dados_teste['Close'], label= 'Dados Reais (Teste)', color='green')
plt.plot(previsao['ds'], previsao['yhat'], label='Previsão', color='orange', linestyle='--')

plt.axvline(dados_treino['Date'].max(), color='red', linestyle='--', label='Inicio da Previsão')
plt.xlabel('Data')
plt.ylabel('Preço Fechamento')
plt.title('Previsão de Preço de Fechamento vs Dados Reais')
plt.legend()
plt.show()
